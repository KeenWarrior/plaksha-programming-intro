# %%
def printing(a, b):
    print(a, b, c)
    c=10

# %%
printing(10, 20)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-e2498a10dc2e> in <module>
# ----> 1 printing(10, 20)
#
# <ipython-input-18-513352d27a32> in printing(a, b)
#       1 def printing(a, b):
# ----> 2     print(a, b, c)
#       3     c=10
#       4
#       5
#
# UnboundLocalError: local variable 'c' referenced before assignment
